# %% [markdown]
# ## Import dataframe

# %%
library('rjson')

fileName = 'dend.json'
json_data <- fromJSON(file=fileName)

# %%
json_data
# Out:
# $node_attributes
# $node_attributes[[1]]
# $node_attributes[[1]]$members
# [1] 75
#
# $node_attributes[[1]]$midpoint
# [1] 57.5288
#
# $node_attributes[[1]]$height
# [1] 0.9146
#
# $node_attributes[[1]]$label
# [1] ""
#
# $node_attributes[[1]]$cell_set_accession
# [1] "CS201908210_76"
#
# $node_attributes[[1]]$original_label
# [1] "n1"
#
# $node_attributes[[1]]$cell_set_label
# [1] "All cells"
#
# $node_attributes[[1]]$cell_set_preferred_alias
# [1] ""
#
# $node_attributes[[1]]$cell_set_aligned_alias
# [1] ""
#
# $node_attributes[[1]]$cell_set_additional_aliases
# [1] ""
#
# $node_attributes[[1]]$cell_set_structure
# [1] "neocortex"
#
# $node_attributes[[1]]$cell_set_alias_assignee
# [1] "Trygve Bakken||"
#
# $node_attributes[[1]]$cell_set_alias_citation
# [1] "10.1038/s41586-019-1506-7||"
#
# $node_attributes[[1]]$cell_set_ontology_tag
# [1] "UBERON:0001950"
#
# $node_attributes[[1]]$taxonomy_id
# [1] "CCN201908210"
#
# $node_attributes[[1]]$`_row`
# [1] "n1"
#
#
#
# $children
# ...
